# %% [markdown]
# # EDA with Visuals
# Create visualizations to answer the quiz questions below this notebook. Use the `winequality_edited.csv` dataset, which you should've created  in the previous concept: *Appending Data (cont.)*.

# %%
# Load dataset
import pandas as pd
import numpy as np

% %matplotlib inline

df = pd.read_csv('winequality_edited.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  white
# 1      9.5        6  white
# ...

# %% [markdown]
# ## Objective

# %% [markdown]
# **Based on histograms of columns in this dataset,**
#
# **which of the following feature variables appear skewed to the right? Fixed Acidity, Total Sulfur Dioxide, pH, Alcohol**
#
# **Based on scatterplots of quality against different feature variables,**
#
# **which of the following is most likely to have a positive impact on quality? Volatile Acidity, Residual Sugar, pH, Alcohol**

# %% [markdown]
# ### Explore

# %%
print('Shape:',df.shape, '\n')
print('Data Types:\n', df.dtypes, '\n')
print('Info:')
print(df.info(), '\n')
print('Check for null values:'' \n')
print('No of null rows: ',df.columns.isnull().shape)
print('Check for Nan values:'' \n')
print('No of Nan rows: ',df.columns.isna().shape)
# Out:
# Shape: (6497, 13)
#
# Data Types:
#  fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# color                    object
# dtype: object
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# fixed_acidity           6497 non-null float64
# volatile_acidity        6497 non-null float64
# citric_acid             6497 non-null float64
# residual_sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free_sulfur_dioxide     6497 non-null float64
# total_sulfur_dioxide    6497 non-null float64
# ...

# %% [markdown]
# ### Histograms for Various Features

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
df['quality'].plot(kind='hist', figsize=(8,8));

# %%
df['alcohol'].plot(kind='hist', figsize=(8,8));

# %%
df['sulphates'].plot(kind='hist', figsize=(8,8));

# %%
df['pH'].plot(kind='hist', figsize=(8,8));

# %%
df['density'].plot(kind='hist', figsize=(8,8));

# %%
df['total_sulfur_dioxide'].plot(kind='hist', figsize=(8,8));

# %%
df['free_sulfur_dioxide'].plot(kind='hist', figsize=(8,8));

# %%
df['chlorides'].plot(kind='hist', figsize=(8,8));

# %%
df['residual_sugar'].plot(kind='hist', figsize=(8,8));

# %%
df['citric_acid'].plot(kind='hist', figsize=(8,8));

# %%
df['volatile_acidity'].plot(kind='hist', figsize=(8,8));

# %%
df['fixed_acidity'].plot(kind='hist', figsize=(8,8));

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %% [markdown]
# ### Scatterplots of Quality Against Various Features

# %%
df.plot.scatter(y='quality', x='alcohol');

# %%
df.plot.scatter(y='quality', x='volatile_acidity');

# %%
df.plot.scatter(y='quality', x='pH');

# %%
df.plot.scatter(y='quality', x='residual_sugar');

# %% [markdown]
# #### Alcohol level has positive correlation with quality of wine
